# %% [markdown]
# ## Vision Model Alignment Search
# In this notebook, we will walk through how to apply MAS to simplistic vision models trained on cifar10.

# %% [markdown]
# ## Overview
#
# ### 1. Define models
#
# In this tutorial, we will assume that the models are already trained. We can use any pytorch based model architecture.
#
# ### 2. Define input data (and train classification head)
#
# We need a dataset for each model. In this tutorial, we will use the same dataset for both models. In principle, however, these datasets can be different. We will also be using cifar10 as our dataset. In this notebook, we will also train the classification head on the loaded data. In principle, this step is unnecessary for pretrained models.
#
# ### 3. Collect model intermediates and outputs
#
# Once we have trained models, we will need to collect model responses for each data point in our dataset. This will give us tuples of inputs, intermediate representations, and outputs for each model that can be used to train the MAS transformation matrices.
#
# ### 4. Train the MAS alignment (i.e. rotation matrices)
#
# Using our data tuples, we can systematically select source and target models, patch from the source into the target intermediate representations using an interchange intervention, and then use the output distribution of the source model as the training objective for the transformation matrices. We train until convergence.
#
# ### 5. Evaluate the alignment
#
# Finally, we will evaluate the alignment on the cifar 10 test set.

# %% [markdown]
# # 1. Define the Models

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vis_training import get_model_and_processor

overwrite = True

models = []
processors = []

#model_names = [
#    "microsoft/resnet-18",
#    "microsoft/resnet-18",
#]
model_names = [
    "microsoft/resnet-18",
    "google/vit-base-patch16-224",
    #"google/vit-base-patch16-224",
]
for model_name in model_names:
    # Models are defined as the backbone (frozen parameters, no head)
    # with an untrained head (unfrozen parameters) that will be trained
    # on the cifar10 dataset before training the MAS alignment
    model, proc = get_model_and_processor(model_name)
    models.append(model.cpu())
    processors.append(proc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 24
#      12 model_names = [
#      13     "microsoft/resnet-18",
#      14     "Kalray/vgg-19",
#    (...)
#      18     #"google/vit-base-patch16-224",
#      19 ]
#      20 for model_name in model_names:
#      21     # Models are defined as the backbone (frozen parameters, no head)
#      22     # with an untrained head (unfrozen parameters) that will be trained
#      23     # on the cifar10 dataset before training the MAS alignment
# ---> 24     model, proc = get_model_and_processor(model_name)
#      25     models.append(model.cpu())
#      26     processors.append(proc)
#
# File ~/src/mas/vision/vis_training.py:34, in get_model_and_processor(model_name, pretrained)
#      22 def get_model_and_processor(model_name, pretrained=True):
#      23     """
#      24     Get a model and processor for a given model name.
#      25
#    (...)
#      32     - "google/vit-huge-patch16-224"
#      33     """
# ---> 34     model = AutoModel.from_pretrained(model_name)
#      35     if not pretrained:
#      36         for p in model.parameters():
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:549, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     546 if kwargs.get("quantization_config") is not None:
#     547     _ = kwargs.pop("quantization_config")
# --> 549 config, kwargs = AutoConfig.from_pretrained(
#     550     pretrained_model_name_or_path,
#     551     return_unused_kwargs=True,
#     552     code_revision=code_revision,
#     553     _commit_hash=commit_hash,
#     554     **hub_kwargs,
#     555     **kwargs,
#     556 )
#     558 # if torch_dtype=auto was passed here, ensure to pass it on
#     559 if kwargs_orig.get("torch_dtype", None) == "auto":
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/auto/configuration_auto.py:1329, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1326         if pattern in str(pretrained_model_name_or_path):
#    1327             return CONFIG_MAPPING[pattern].from_dict(config_dict, **unused_kwargs)
# -> 1329 raise ValueError(
#    1330     f"Unrecognized model in {pretrained_model_name_or_path}. "
#    1331     f"Should have a `model_type` key in its {CONFIG_NAME}, or contain one of the following strings "
#    1332     f"in its name: {', '.join(CONFIG_MAPPING.keys())}"
#    1333 )
#
# ValueError: Unrecognized model in Kalray/vgg-19. Should have a `model_type` key in its config.json, or contain one of the following strings in its name: aimv2, aimv2_vision_model, albert, align, altclip, apertus, arcee, aria, aria_text, audio-spectrogram-transformer, autoformer, aya_vision, bamba, bark, bart, beit, bert, bert-generation, big_bird, bigbird_pegasus, biogpt, bit, bitnet, blenderbot, blenderbot-small, blip, blip-2, blip_2_qformer, bloom, bridgetower, bros, camembert, canine, chameleon, chinese_clip, chinese_clip_vision_model, clap, clip, clip_text_model, clip_vision_model, clipseg, clvp, code_llama, codegen, cohere, cohere2, cohere2_vision, colpali, colqwen2, conditional_detr, convbert, convnext, convnextv2, cpmant, csm, ctrl, cvt, d_fine, dab-detr, dac, data2vec-audio, data2vec-text, data2vec-vision, dbrx, deberta, deberta-v2, decision_transformer, deepseek_v2, deepseek_v3, deepseek_vl, deepseek_vl_hybrid, deformable_detr, deit, depth_anything, depth_pro, deta, detr, dia, diffllama, dinat, dinov2, dinov2_with_registers, dinov3_convnext, dinov3_vit, distilbert, doge, donut-swin, dots1, dpr, dpt, efficientformer, efficientloftr, efficientnet, electra, emu3, encodec, encoder-decoder, eomt, ernie, ernie4_5, ernie4_5_moe, ernie_m, esm, evolla, exaone4, falcon, falcon_h1, falcon_mamba, fastspeech2_conformer, fastspeech2_conformer_with_hifigan, flaubert, flava, florence2, fnet, focalnet, fsmt, funnel, fuyu, gemma, gemma2, gemma3, gemma3_text, gemma3n, gemma3n_audio, gemma3n_text, gemma3n_vision, git, glm, glm4, glm4_moe, glm4v, glm4v_moe, glm4v_moe_text, glm4v_text, glpn, got_ocr2, gpt-sw3, gpt2, gpt_bigcode, gpt_neo, gpt_neox, gpt_neox_japanese, gpt_oss, gptj, gptsan-japanese, granite, granite_speech, granitemoe, granitemoehybrid, granitemoeshared, granitevision, graphormer, grounding-dino, groupvit, helium, hgnet_v2, hiera, hubert, hunyuan_v1_dense, hunyuan_v1_moe, ibert, idefics, idefics2, idefics3, idefics3_vision, ijepa, imagegpt, informer, instructblip, instructblipvideo, internvl, internvl_vision, jamba, janus, jetmoe, jukebox, kosmos-2, kosmos-2.5, kyutai_speech_to_text, layoutlm, layoutlmv2, layoutlmv3, led, levit, lfm2, lightglue, lilt, llama, llama4, llama4_text, llava, llava_next, llava_next_video, llava_onevision, longformer, longt5, luke, lxmert, m2m_100, mamba, mamba2, marian, markuplm, mask2former, maskformer, maskformer-swin, mbart, mctct, mega, megatron-bert, metaclip_2, mgp-str, mimi, minimax, mistral, mistral3, mixtral, mlcd, mllama, mm-grounding-dino, mobilebert, mobilenet_v1, mobilenet_v2, mobilevit, mobilevitv2, modernbert, modernbert-decoder, moonshine, moshi, mpnet, mpt, mra, mt5, musicgen, musicgen_melody, mvp, nat, nemotron, nezha, nllb-moe, nougat, nystromformer, olmo, olmo2, olmoe, omdet-turbo, oneformer, open-llama, openai-gpt, opt, ovis2, owlv2, owlvit, paligemma, patchtsmixer, patchtst, pegasus, pegasus_x, perceiver, perception_encoder, perception_lm, persimmon, phi, phi3, phi4_multimodal, phimoe, pix2struct, pixtral, plbart, poolformer, pop2piano, prompt_depth_anything, prophetnet, pvt, pvt_v2, qdqbert, qwen2, qwen2_5_omni, qwen2_5_vl, qwen2_5_vl_text, qwen2_audio, qwen2_audio_encoder, qwen2_moe, qwen2_vl, qwen2_vl_text, qwen3, qwen3_moe, rag, realm, recurrent_gemma, reformer, regnet, rembert, resnet, retribert, roberta, roberta-prelayernorm, roc_bert, roformer, rt_detr, rt_detr_resnet, rt_detr_v2, rwkv, sam, sam2, sam2_hiera_det_model, sam2_video, sam2_vision_model, sam_hq, sam_hq_vision_model, sam_vision_model, seamless_m4t, seamless_m4t_v2, seed_oss, segformer, seggpt, sew, sew-d, shieldgemma2, siglip, siglip2, siglip_vision_model, smollm3, smolvlm, smolvlm_vision, speech-encoder-decoder, speech_to_text, speech_to_text_2, speecht5, splinter, squeezebert, stablelm, starcoder2, superglue, superpoint, swiftformer, swin, swin2sr, swinv2, switch_transformers, t5, t5gemma, table-transformer, tapas, textnet, time_series_transformer, timesfm, timesformer, timm_backbone, timm_wrapper, trajecto ...

# %% [markdown]
# # 2. Load the input data (and labels) and finetune

# %%
import torch
from vis_training import train_model, get_dataloaders, get_datasets
from torchvision import datasets
import os

batch_size = 128
val_batch_size = 1000
num_workers = 1
num_epochs = 5
lr = 0.001
model_save_dir = "/data2/grantsrb/vision_mas/models"
data_root = "/data2/grantsrb/torch_datasets"
dataset_name = "fashion-mnist"

train_ds, test_ds = get_datasets(dataset_name, data_root)

train_loaders = []
test_loaders = []
for i, processor in enumerate(processors):
    train_loader, test_loader = get_dataloaders(
        train_dataset=train_ds,
        test_dataset=test_ds,
        processor=processor,
        batch_size=batch_size,
        val_batch_size=val_batch_size,
        num_workers=num_workers,
        data_root=data_root,
    )
    train_loaders.append(train_loader)
    test_loaders.append(test_loader)
# Out:
# Loading fashion-mnist...
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                      | 23.0M/26.4M [06:21<01:34, 36.0kB/s]

# %%
dir(train_ds)

# %%
import numpy as np
idxs = np.arange(5)
len(train_ds.data[idxs])
len(train_ds.targets[idxs])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       2 idxs = np.arange(5)
#       3 len(train_ds.data[idxs])
# ----> 4 len(train_ds.targets[idxs])
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
for i, (model, processor) in enumerate(zip(models, processors)):
    train_loader = train_loaders[i]
    test_loader = test_loaders[i]
    model_name = model_names[i].replace("/", "_")
    model_save_path = f"{model_save_dir}/{model_name}_{dataset_name}_sd_{i}.pt"
    if os.path.exists(model_save_path):
        print(f"Loading model from {model_save_path}")
        model.load_state_dict(torch.load(model_save_path))
    else:
        print(f"Finetuning model {i}")
        try:
            model = train_model(
                model=model,
                train_loader=train_loader,
                test_loader=test_loader,
                hyperparameters={"lr": lr, "num_epochs": num_epochs},
            )
        except KeyboardInterrupt:
            print("Interrupted training, continuing...")
            pass
    
    # From here on, we will not update the model parameters
    for p in model.parameters():
        p.requires_grad = False
    
    torch.save(model.state_dict(), model_save_path)
# Out:
# Finetuning model 0
# Epoch 0, Batch 0, Loss: 3.0153627395629883, Acc: 0.0625
# Epoch 0, Batch 100, Loss: 0.5366522073745728, Acc: 0.8828125
# Epoch 0, Batch 200, Loss: 0.34541866183280945, Acc: 0.9296875
# Epoch 0, Batch 300, Loss: 0.3610914647579193, Acc: 0.9140625
# Epoch 0, Batch 400, Loss: 0.1765606552362442, Acc: 0.9765625
# Validating...
# 0it [00:01, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[9], line 12
#      10 print(f"Finetuning model {i}")
#      11 try:
# ---> 12     model = train_model(
#      13         model=model,
#      14         train_loader=train_loader,
#      15         test_loader=test_loader,
#      16         hyperparameters={"lr": lr, "num_epochs": num_epochs},
#      17     )
#      18 except KeyboardInterrupt:
#      19     print("Interrupted training, continuing...")
#
# File ~/src/mas/vision/vis_training.py:188, in train_model(model, train_loader, test_loader, verbose, hyperparameters)
#     186 labels = labels.to(device)
#     187 with torch.no_grad():
# --> 188     outputs = model(pixel_values)
#     189     loss = nn.functional.cross_entropy(outputs, labels)
#     190     acc = (outputs.argmax(dim=1) == labels).float().mean()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/src/mas/vision/torch_modules.py:226, in ViTWithLinearHead.forward(self, pixel_values)
#     221 def forward(self, pixel_values):
#     222     """
#     223     pixel_values: (B, 3, H, W) already preprocessed by AutoImageProcessor
#     224     Uses the CLS token representation for classification.
#     225     """
# --> 226     outputs = self.backbone(pixel_values=pixel_values)
#     227     # For ViT models, outputs.last_hidden_state[:, 0] is the [CLS] token
#     228     cls = outputs.last_hidden_state[:, 0]
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:1064, in check_model_inputs.<locals>.wrapper(self, *args, **kwargs)
#    1061                 module.forward = make_capture_wrapper(module, original_forward, key, specs.index)
#    1062                 monkey_patched_layers.append((module, original_forward))
# -> 1064 outputs = func(self, *args, **kwargs)
#    1065 # Restore original forward methods
#    1066 for module, original_forward in monkey_patched_layers:
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/vit/modeling_vit.py:486, in ViTModel.forward(self, pixel_values, bool_masked_pos, head_mask, interpolate_pos_encoding, **kwargs)
#     480     pixel_values = pixel_values.to(expected_dtype)
#     482 embedding_output = self.embeddings(
#     483     pixel_values, bool_masked_pos=bool_masked_pos, interpolate_pos_encoding=interpolate_pos_encoding
#     484 )
# --> 486 encoder_outputs: BaseModelOutput = self.encoder(embedding_output, head_mask=head_mask)
#     488 sequence_output = encoder_outputs.last_hidden_state
#     489 sequence_output = self.layernorm(sequence_output)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/vit/modeling_vit.py:369, in ViTEncoder.forward(self, hidden_states, head_mask)
#     367 for i, layer_module in enumerate(self.layer):
#     368     layer_head_mask = head_mask[i] if head_mask is not None else None
# --> 369     hidden_states = layer_module(hidden_states, layer_head_mask)
#     371 return BaseModelOutput(last_hidden_state=hidden_states)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/vit/modeling_vit.py:351, in ViTLayer.forward(self, hidden_states, head_mask)
#     349 # in ViT, layernorm is also applied after self-attention
#     350 layer_output = self.layernorm_after(hidden_states)
# --> 351 layer_output = self.intermediate(layer_output)
#     353 # second residual connection is done here
#     354 layer_output = self.output(layer_output, hidden_states)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/vit/modeling_vit.py:311, in ViTIntermediate.forward(self, hidden_states)
#     310 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 311     hidden_states = self.dense(hidden_states)
#     312     hidden_states = self.intermediate_act_fn(hidden_states)
#     313     return hidden_states
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.26 GiB. GPU 0 has a total capacity of 44.35 GiB of which 1006.81 MiB is free. Process 2203241 has 25.69 GiB memory in use. Process 2237463 has 13.42 GiB memory in use. Including non-PyTorch memory, this process has 4.22 GiB memory in use. Of the allocated memory 3.77 GiB is allocated by PyTorch, and 96.10 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# # 3. Collect model intermediates and outputs

# %%
import torch
from vis_training import get_actvs_data, get_dataloader

layer_names = [ # need a layer name for each model
    "backbone.encoder.stages.1.layers.0",
    "backbone.encoder.stages.1.layers.0",
]

# %%
actvs_train_sets = []
actvs_valid_sets = []

device = 0 if torch.cuda.is_available() else "cpu"
z = zip(models, processors, layer_names)
for i, (model, processor, layer_name) in enumerate(z):
    print(f"Collecting actvs for model {i}")
    model.eval()
    model.to(device)
    train_loader = get_dataloader(
        dataset=train_ds,
        processor=processor,
        batch_size=1000,
        num_workers=num_workers,
        shuffle=False,
    )
    model.cpu()
    
    train_save_path = f"{model_save_dir}/actvs_train_set_{i}.pt"
    valid_save_path = f"{model_save_dir}/actvs_valid_set_{i}.pt"
    if os.path.exists(train_save_path) and not overwrite:
        print(f"Loading training set from {train_save_path}")
        train_set = torch.load(train_save_path)
        valid_set = torch.load(valid_save_path)
    else:
        # the actvs data is a dict of "inputs" (B,C,H,W), "labels" (B,),
        # "actvs" (B,D,H,W) or (B,D), "logits" (B,C), "preds" (B,).
        # Note that because this is a non-sequential setting, we could make
        # the whole process more efficient by ignoring all processing layers
        # leading up to the layer of interest, but that requires us to know
        # the architecture of the model.
        with torch.no_grad():
            print(f"Collecting training set")
            train_set = get_actvs_data(
                model=model,
                data_loader=train_loader,
                layer_name=layer_name,
                verbose=True,
            )
    
            print(f"Collecting validation set")
            valid_set = get_actvs_data(
                model=model,
                data_loader=test_loader,
                layer_name=layer_name,
                verbose=True,
            )
        torch.save(train_set, train_save_path)
        torch.save(valid_set, valid_save_path)
    actvs_train_sets.append(train_set)
    actvs_valid_sets.append(valid_set)
    model.cpu()
# Out:
# Collecting actvs for model 0
# Collecting training set
#   3%|█████▊                                                                                                                                                                          | 2/60 [00:16<08:08,  8.42s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 34
#      32 with torch.no_grad():
#      33     print(f"Collecting training set")
# ---> 34     train_set = get_actvs_data(
#      35         model=model,
#      36         data_loader=train_loader,
#      37         layer_name=layer_name,
#      38         verbose=True,
#      39     )
#      41     print(f"Collecting validation set")
#      42     valid_set = get_actvs_data(
#      43         model=model,
#      44         data_loader=test_loader,
#      45         layer_name=layer_name,
#      46         verbose=True,
#      47     )
#
# File ~/src/mas/vision/vis_training.py:205, in get_actvs_data(model, data_loader, layer_name, verbose)
#     203 labels_list = []
#     204 itr = tqdm(data_loader) if verbose else data_loader
# --> 205 for pixel_values, labels in itr:
#     206     pixel_values = pixel_values.to(device)
#     207     labels = labels.to(device)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/src/mas/vision/torch_modules.py:214, in BackboneWithLinearHead.forward(self, pixel_values)
#     213 def forward(self, pixel_values):
# --> 214     outputs = self.backbone(pixel_values)
#     215     outputs = outputs["pooler_output"]
#     216     return self.classifier(outputs.flatten(1))
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/resnet/modeling_resnet.py:291, in ResNetModel.forward(self, pixel_values, output_hidden_states, return_dict)
#     287 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     289 embedding_output = self.embedder(pixel_values)
# --> 291 encoder_outputs = self.encoder(
#     292     embedding_output, output_hidden_states=output_hidden_states, return_dict=return_dict
#     293 )
#     295 last_hidden_state = encoder_outputs[0]
#     297 pooled_output = self.pooler(last_hidden_state)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/resnet/modeling_resnet.py:233, in ResNetEncoder.forward(self, hidden_state, output_hidden_states, return_dict)
#     230     if output_hidden_states:
#     231         hidden_states = hidden_states + (hidden_state,)
# --> 233     hidden_state = stage_module(hidden_state)
#     235 if output_hidden_states:
#     236     hidden_states = hidden_states + (hidden_state,)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/resnet/modeling_resnet.py:202, in ResNetStage.forward(self, input)
#     200 hidden_state = input
#     201 for layer in self.layers:
# --> 202     hidden_state = layer(hidden_state)
#     203 return hidden_state
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/resnet/modeling_resnet.py:119, in ResNetBasicLayer.forward(self, hidden_state)
#     117 def forward(self, hidden_state):
#     118     residual = hidden_state
# --> 119     hidden_state = self.layer(hidden_state)
#     120     residual = self.shortcut(residual)
#     121     hidden_state += residual
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/models/resnet/modeling_resnet.py:53, in ResNetConvLayer.forward(self, input)
#      52 def forward(self, input: Tensor) -> Tensor:
# ---> 53     hidden_state = self.convolution(input)
#      54     hidden_state = self.normalization(hidden_state)
#      55     hidden_state = self.activation(hidden_state)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:

# %%
torch.save(actvs_train_sets, f"{model_save_dir}/actvs_train_sets.pt")
torch.save(actvs_valid_sets, f"{model_save_dir}/actvs_valid_sets.pt")

# %%
actvs_train_sets = torch.load(f"{model_save_dir}/actvs_train_sets.pt")
actvs_valid_sets = torch.load(f"{model_save_dir}/actvs_valid_sets.pt")

# %% [markdown]
# # 4. Instantiate the MAS alignment object

# %%
og_models = [model for model in models]
og_processors = [processor for processor in processors]
og_layer_names = [layer_name for layer_name in layer_names]
og_actvs_train_sets = [actvs_train_set for actvs_train_set in actvs_train_sets]
og_actvs_valid_sets = [actvs_valid_set for actvs_valid_set in actvs_valid_sets]

# %%
from alignment import MASAlignment
from hooks import hook_vision_model

subspace_size = 128 # number of dimensions used in the patching
mtx_type = "orthogonal"
normalize = False # learns to normalize the activations before the transformation matrix
batch_norm = True
identity_rot = False # uses the identity rotation matrix (only use for debugging)
debug = False

if debug:
    models = [og_models[0] for _ in models]
    processors = [og_processors[0] for _ in processors]
    layer_names = [og_layer_names[0] for _ in layer_names]
    actvs_train_sets = [og_actvs_train_sets[0] for _ in actvs_train_sets]
    actvs_valid_sets = [og_actvs_valid_sets[0] for _ in actvs_valid_sets]
else:
    models = [model for model in og_models]
    processors = [processor for processor in og_processors]
    layer_names = [layer_name for layer_name in og_layer_names]
    actvs_train_sets = [actvs_train_set for actvs_train_set in og_actvs_train_sets]
    actvs_valid_sets = [actvs_valid_set for actvs_valid_set in og_actvs_valid_sets]

# the alignment object contains the transformation matrices for each model
# and the patching masks for each model. It also contains the logic for
# performing an alignment intervention (i.e. transferring causal activity
# from a source model to a target model).
alignment = MASAlignment(
    model_dims=[data["actvs"].shape[1] for data in actvs_train_sets],
    mtx_type=mtx_type,
    subspace_sizes=subspace_size,
    normalize=normalize,
    batch_norm=batch_norm,
    identity_rot=identity_rot,
)

# We need to hook the models in order to perform the patching intervention
# at the desired layer.
try:
    hooks = [hook.remove() for hook in hooks]
except:
    pass

hooks = []
for model,layer in zip(models, layer_names):
    hooks.append(
        hook_vision_model(model, layer, alignment)
    )
# Out:
# Using subspace sizes: [128]

# %% [markdown]
# # 5. Train the MAS alignment

# %%
from vis_training import train_mas_alignment_one_epoch, evaluate_mas_alignment
import torch.optim as optim
import numpy as np
import pandas as pd

num_epochs = 25
batch_size = 256
lr = 0.0005
one_hot_loss = False
label_smoothing = 0.0
train_directions = None
ground_truth_labels = False
val_batch_size = 1000

device = 0 if torch.cuda.is_available() else "cpu"
alignment.to(device)
alignment.train()
optimizer = optim.RMSprop(alignment.parameters(), lr=lr)
train_dfs = []
valid_dfs = []
for epoch in range(num_epochs):
    print(f"Epoch {epoch} - Training")
    train_df = train_mas_alignment_one_epoch(
        models=models,
        alignment=alignment,
        actvs_sets=actvs_train_sets,
        batch_size=batch_size,
        optimizer=optimizer,
        one_hot_loss=one_hot_loss,
        label_smoothing=label_smoothing,
        train_directions=train_directions,
        use_ground_truth_labels=ground_truth_labels,
    )
    print(f"Epoch {epoch} - Validating")
    valid_df = evaluate_mas_alignment(
        models=models,
        alignment=alignment,
        actvs_sets=actvs_valid_sets,
        batch_size=val_batch_size,
        one_hot_loss=one_hot_loss,
        use_ground_truth_labels=ground_truth_labels,
    )

    cols = ["actn_loss","cl_loss","acc"]
    groups = ["src_idx","trg_idx"]

    train = train_df.groupby(groups)[cols].mean().reset_index()
    train["epoch"] = epoch
    train_dfs.append(train)

    valid = valid_df.groupby(groups)[cols].mean().reset_index()
    valid["epoch"] = epoch
    valid_dfs.append(valid)
    print()
    print(train.sort_values(by=groups,ascending=True))
    valid.columns = ["valid_"+col if col in cols else col for col in valid.columns]
    print(valid.sort_values(by=groups,ascending=True))
    print(
        "Train IIA:", round(np.min(train["acc"]), 5),
        "|| Loss:", round(np.max(train["actn_loss"]), 5)
    )
    print(
        "Valid IIA:", round(np.min(valid["valid_acc"]), 5),
        "|| Loss:", round(np.max(valid["valid_actn_loss"]), 5)
    )
# Out:
# Epoch 0
# Batch 9984/10000 IIA: 0.9375 Loss: 0.6057357788085938
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566333      0.0  0.999841      0
# 1        0        1   0.688486      0.0  0.874251      0
# 2        1        0   0.689693      0.0  0.872684      0
# 3        1        1   0.566333      0.0  0.999920      0
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000      0
# 1        0        1         0.694260            0.0   0.873145      0
# 2        1        0         0.692942            0.0   0.872363      0
# 3        1        1         0.572126            0.0   1.000000      0
# Train IIA: 0.87268 || Loss: 0.68969
# Valid IIA: 0.87236 || Loss: 0.69426
# Epoch 1
# Batch 9984/10000 IIA: 0.9375 Loss: 0.6039549112319946
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566701      0.0  0.999880      1
# 1        0        1   0.661584      0.0  0.887508      1
# 2        1        0   0.662543      0.0  0.888321      1
# 3        1        1   0.566701      0.0  0.999880      1
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000      1
# 1        0        1         0.673098            0.0   0.882910      1
# 2        1        0         0.675187            0.0   0.886133      1
# 3        1        1         0.572126            0.0   1.000000      1
# Train IIA: 0.88751 || Loss: 0.66254
# Valid IIA: 0.88291 || Loss: 0.67519
# Epoch 2
# Batch 9984/10000 IIA: 0.9375 Loss: 0.6011230945587158
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566746      0.0  0.999880      2
# 1        0        1   0.647643      0.0  0.897361      2
# 2        1        0   0.648103      0.0  0.895950      2
# 3        1        1   0.566746      0.0  0.999880      2
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000      2
# 1        0        1         0.656188            0.0   0.892871      2
# 2        1        0         0.659409            0.0   0.890332      2
# 3        1        1         0.572126            0.0   1.000000      2
# Train IIA: 0.89595 || Loss: 0.6481
# Valid IIA: 0.89033 || Loss: 0.65941
# Epoch 3
# Batch 9984/10000 IIA: 0.8125 Loss: 0.6236710548400879
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566647      0.0  0.999880      3
# 1        0        1   0.636422      0.0  0.904297      3
# 2        1        0   0.637101      0.0  0.903360      3
# 3        1        1   0.566647      0.0  0.999880      3
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000      3
# 1        0        1         0.646812            0.0   0.896484      3
# 2        1        0         0.648982            0.0   0.895020      3
# 3        1        1         0.572126            0.0   1.000000      3
# Train IIA: 0.90336 || Loss: 0.6371
# Valid IIA: 0.89502 || Loss: 0.64898
# Epoch 4
# Batch 9984/10000 IIA: 0.9375 Loss: 0.6053153872489929
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566894      0.0  0.999880      4
# 1        0        1   0.628325      0.0  0.911292      4
# 2        1        0   0.628163      0.0  0.911217      4
# 3        1        1   0.566894      0.0  0.999841      4
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000      4
# 1        0        1         0.638565            0.0   0.902441      4
# 2        1        0         0.637706            0.0   0.906152      4
# 3        1        1         0.572126            0.0   1.000000      4
# Train IIA: 0.91122 || Loss: 0.62833
# Valid IIA: 0.90244 || Loss: 0.63856
# Epoch 5
# Batch 9984/10000 IIA: 0.875 Loss: 0.5863757133483887
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566906      0.0  0.999880      5
# 1        0        1   0.620697      0.0  0.915617      5
# 2        1        0   0.621046      0.0  0.916458      5
# 3        1        1   0.566906      0.0  0.999841      5
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000      5
# 1        0        1         0.631956            0.0   0.908887      5
# 2        1        0         0.629727            0.0   0.909863      5
# 3        1        1         0.572126            0.0   1.000000      5
# Train IIA: 0.91562 || Loss: 0.62105
# Valid IIA: 0.90889 || Loss: 0.63196
# Epoch 6
# Batch 9984/10000 IIA: 0.9375 Loss: 0.5857520699501038
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566870      0.0  0.999860      6
# 1        0        1   0.614808      0.0  0.920855      6
# 2        1        0   0.614942      0.0  0.919400      6
# 3        1        1   0.566870      0.0  0.999900      6
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000      6
# 1        0        1         0.626131            0.0   0.916406      6
# 2        1        0         0.629429            0.0   0.912305      6
# 3        1        1         0.572126            0.0   1.000000      6
# Train IIA: 0.9194 || Loss: 0.61494
# Valid IIA: 0.9123 || Loss: 0.62943
# Epoch 7
# Batch 9984/10000 IIA: 0.875 Loss: 0.5616797208786011
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566632      0.0  0.999860      7
# 1        0        1   0.609292      0.0  0.924231      7
# 2        1        0   0.609359      0.0  0.924984      7
# 3        1        1   0.566632      0.0  0.999880      7
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000      7
# 1        0        1         0.620165            0.0   0.917578      7
# 2        1        0         0.616852            0.0   0.922363      7
# 3        1        1         0.572126            0.0   0.999902      7
# Train IIA: 0.92423 || Loss: 0.60936
# Valid IIA: 0.91758 || Loss: 0.62016
# Epoch 8
# Batch 9984/10000 IIA: 0.9375 Loss: 0.5663870573043823
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566682      0.0  0.999880      8
# 1        0        1   0.605037      0.0  0.928946      8
# 2        1        0   0.605257      0.0  0.929014      8
# 3        1        1   0.566682      0.0  0.999860      8
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000      8
# 1        0        1         0.611914            0.0   0.925391      8
# 2        1        0         0.613519            0.0   0.925293      8
# 3        1        1         0.572126            0.0   1.000000      8
# Train IIA: 0.92895 || Loss: 0.60526
# Valid IIA: 0.92529 || Loss: 0.61352
# Epoch 9
# Batch 9984/10000 IIA: 0.9375 Loss: 0.554037868976593
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566485      0.0  0.999880      9
# 1        0        1   0.601356      0.0  0.932541      9
# 2        1        0   0.601381      0.0  0.933761      9
# 3        1        1   0.566485      0.0  0.999841      9
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   0.999902      9
# 1        0        1         0.607545            0.0   0.929590      9
# 2        1        0         0.608500            0.0   0.928613      9
# 3        1        1         0.572126            0.0   1.000000      9
# Train IIA: 0.93254 || Loss: 0.60138
# Valid IIA: 0.92861 || Loss: 0.6085
# Epoch 10
# Batch 9984/10000 IIA: 0.9375 Loss: 0.5560723543167114
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566823      0.0  0.999940     10
# 1        0        1   0.598450      0.0  0.936141     10
# 2        1        0   0.598543      0.0  0.934941     10
# 3        1        1   0.566823      0.0  0.999880     10
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     10
# 1        0        1         0.616475            0.0   0.921582     10
# 2        1        0         0.617903            0.0   0.921582     10
# 3        1        1         0.572126            0.0   1.000000     10
# Train IIA: 0.93494 || Loss: 0.59854
# Valid IIA: 0.92158 || Loss: 0.6179
# Epoch 11
# Batch 9984/10000 IIA: 1.0 Loss: 0.554907500743866
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566515      0.0  0.999900     11
# 1        0        1   0.595729      0.0  0.938138     11
# 2        1        0   0.595456      0.0  0.938309     11
# 3        1        1   0.566515      0.0  0.999841     11
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     11
# 1        0        1         0.599833            0.0   0.939941     11
# 2        1        0         0.600499            0.0   0.936230     11
# 3        1        1         0.572126            0.0   1.000000     11
# Train IIA: 0.93814 || Loss: 0.59573
# Valid IIA: 0.93623 || Loss: 0.6005
# Epoch 12
# Batch 9984/10000 IIA: 0.9375 Loss: 0.5431859493255615
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566544      0.0  0.999880     12
# 1        0        1   0.593979      0.0  0.939210     12
# 2        1        0   0.593866      0.0  0.939931     12
# 3        1        1   0.566544      0.0  0.999860     12
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     12
# 1        0        1         0.598370            0.0   0.941504     12
# 2        1        0         0.598417            0.0   0.940039     12
# 3        1        1         0.572126            0.0   1.000000     12
# Train IIA: 0.93921 || Loss: 0.59398
# Valid IIA: 0.94004 || Loss: 0.59842
# Epoch 13
# Batch 9984/10000 IIA: 0.9375 Loss: 0.5415310859680176
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566291      0.0  0.999801     13
# 1        0        1   0.590959      0.0  0.942482     13
# 2        1        0   0.591262      0.0  0.942710     13
# 3        1        1   0.566291      0.0  0.999821     13
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     13
# 1        0        1         0.595306            0.0   0.944922     13
# 2        1        0         0.595555            0.0   0.942090     13
# 3        1        1         0.572126            0.0   1.000000     13
# Train IIA: 0.94248 || Loss: 0.59126
# Valid IIA: 0.94209 || Loss: 0.59555
# Epoch 14
# Batch 9984/10000 IIA: 0.9375 Loss: 0.5438711643218994
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566855      0.0  0.999880     14
# 1        0        1   0.590790      0.0  0.943973     14
# 2        1        0   0.590553      0.0  0.944727     14
# 3        1        1   0.566855      0.0  0.999781     14
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     14
# 1        0        1         0.595052            0.0   0.946777     14
# 2        1        0         0.596173            0.0   0.942383     14
# 3        1        1         0.572126            0.0   1.000000     14
# Train IIA: 0.94397 || Loss: 0.59079
# Valid IIA: 0.94238 || Loss: 0.59617
# Epoch 15
# Batch 9984/10000 IIA: 1.0 Loss: 0.5404344797134399
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566450      0.0  0.999821     15
# 1        0        1   0.588515      0.0  0.946616     15
# 2        1        0   0.588296      0.0  0.945811     15
# 3        1        1   0.566450      0.0  0.999801     15
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     15
# 1        0        1         0.593585            0.0   0.947559     15
# 2        1        0         0.593114            0.0   0.947461     15
# 3        1        1         0.572126            0.0   1.000000     15
# Train IIA: 0.94581 || Loss: 0.58852
# Valid IIA: 0.94746 || Loss: 0.59358
# Epoch 16
# Batch 9984/10000 IIA: 1.0 Loss: 0.541650652885437
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566582      0.0  0.999880     16
# 1        0        1   0.587551      0.0  0.948585     16
# 2        1        0   0.587487      0.0  0.947433     16
# 3        1        1   0.566582      0.0  0.999900     16
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     16
# 1        0        1         0.590429            0.0   0.950293     16
# 2        1        0         0.590090            0.0   0.950684     16
# 3        1        1         0.572126            0.0   1.000000     16
# Train IIA: 0.94743 || Loss: 0.58755
# Valid IIA: 0.95029 || Loss: 0.59043
# Epoch 17
# Batch 9984/10000 IIA: 1.0 Loss: 0.541039228439331
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566666      0.0  0.999841     17
# 1        0        1   0.586431      0.0  0.949506     17
# 2        1        0   0.585882      0.0  0.949956     17
# 3        1        1   0.566666      0.0  0.999880     17
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   0.999902     17
# 1        0        1         0.589579            0.0   0.950684     17
# 2        1        0         0.589205            0.0   0.951367     17
# 3        1        1         0.572126            0.0   1.000000     17
# Train IIA: 0.94951 || Loss: 0.58643
# Valid IIA: 0.95068 || Loss: 0.58958
# Epoch 18
# Batch 9984/10000 IIA: 1.0 Loss: 0.5381015539169312
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566739      0.0  0.999841     18
# 1        0        1   0.585636      0.0  0.949498     18
# 2        1        0   0.585105      0.0  0.951658     18
# 3        1        1   0.566739      0.0  0.999801     18
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     18
# 1        0        1         0.586295            0.0   0.955664     18
# 2        1        0         0.587401            0.0   0.953516     18
# 3        1        1         0.572126            0.0   1.000000     18
# Train IIA: 0.9495 || Loss: 0.58564
# Valid IIA: 0.95352 || Loss: 0.5874
# Epoch 19
# Batch 9984/10000 IIA: 1.0 Loss: 0.5432343482971191
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566658      0.0  0.999940     19
# 1        0        1   0.584362      0.0  0.951471     19
# 2        1        0   0.584248      0.0  0.952427     19
# 3        1        1   0.566658      0.0  0.999880     19
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     19
# 1        0        1         0.589934            0.0   0.951660     19
# 2        1        0         0.589617            0.0   0.949512     19
# 3        1        1         0.572126            0.0   1.000000     19
# Train IIA: 0.95147 || Loss: 0.58436
# Valid IIA: 0.94951 || Loss: 0.58993
# Epoch 20
# Batch 9984/10000 IIA: 1.0 Loss: 0.5382972955703735
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566594      0.0  0.999880     20
# 1        0        1   0.584023      0.0  0.951602     20
# 2        1        0   0.584111      0.0  0.951726     20
# 3        1        1   0.566594      0.0  0.999801     20
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0    1.00000     20
# 1        0        1         0.586622            0.0    0.95625     20
# 2        1        0         0.585689            0.0    0.95791     20
# 3        1        1         0.572126            0.0    1.00000     20
# Train IIA: 0.9516 || Loss: 0.58411
# Valid IIA: 0.95625 || Loss: 0.58662
# Epoch 21
# Batch 9984/10000 IIA: 1.0 Loss: 0.5375250577926636
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566726      0.0  0.999821     21
# 1        0        1   0.582646      0.0  0.954448     21
# 2        1        0   0.582707      0.0  0.954632     21
# 3        1        1   0.566726      0.0  0.999860     21
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     21
# 1        0        1         0.583968            0.0   0.960254     21
# 2        1        0         0.584058            0.0   0.957031     21
# 3        1        1         0.572126            0.0   1.000000     21
# Train IIA: 0.95445 || Loss: 0.58271
# Valid IIA: 0.95703 || Loss: 0.58406
# Epoch 22
# Batch 9984/10000 IIA: 1.0 Loss: 0.5373884439468384
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566527      0.0  0.999880     22
# 1        0        1   0.581653      0.0  0.957139     22
# 2        1        0   0.581273      0.0  0.956481     22
# 3        1        1   0.566527      0.0  0.999860     22
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     22
# 1        0        1         0.584840            0.0   0.959668     22
# 2        1        0         0.584151            0.0   0.958691     22
# 3        1        1         0.572126            0.0   0.999902     22
# Train IIA: 0.95648 || Loss: 0.58165
# Valid IIA: 0.95869 || Loss: 0.58484
# Epoch 23
# Batch 9984/10000 IIA: 1.0 Loss: 0.5431946516036987
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566421      0.0  0.999821     23
# 1        0        1   0.581706      0.0  0.956960     23
# 2        1        0   0.581620      0.0  0.954345     23
# 3        1        1   0.566421      0.0  0.999761     23
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     23
# 1        0        1         0.582851            0.0   0.963867     23
# 2        1        0         0.582742            0.0   0.961523     23
# 3        1        1         0.572126            0.0   1.000000     23
# Train IIA: 0.95434 || Loss: 0.58171
# Valid IIA: 0.96152 || Loss: 0.58285
# Epoch 24
# Batch 9984/10000 IIA: 1.0 Loss: 0.5423148274421692
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566579      0.0  0.999900     24
# 1        0        1   0.580992      0.0  0.956130     24
# 2        1        0   0.580882      0.0  0.956967     24
# 3        1        1   0.566579      0.0  0.999821     24
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     24
# 1        0        1         0.589313            0.0   0.952246     24
# 2        1        0         0.590153            0.0   0.949512     24
# 3        1        1         0.572126            0.0   1.000000     24
# Train IIA: 0.95613 || Loss: 0.58099
# Valid IIA: 0.94951 || Loss: 0.59015
# Epoch 25
# Batch 9984/10000 IIA: 1.0 Loss: 0.5356329679489136
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566623      0.0  0.999860     25
# 1        0        1   0.580796      0.0  0.956154     25
# 2        1        0   0.580716      0.0  0.958135     25
# 3        1        1   0.566623      0.0  0.999880     25
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     25
# 1        0        1         0.581456            0.0   0.965723     25
# 2        1        0         0.581499            0.0   0.962402     25
# 3        1        1         0.572126            0.0   0.999902     25
# Train IIA: 0.95615 || Loss: 0.5808
# Valid IIA: 0.9624 || Loss: 0.5815
# Epoch 26
# Batch 9984/10000 IIA: 1.0 Loss: 0.5330647230148315
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566724      0.0  0.999801     26
# 1        0        1   0.579740      0.0  0.959770     26
# 2        1        0   0.580309      0.0  0.958494     26
# 3        1        1   0.566724      0.0  0.999821     26
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     26
# 1        0        1         0.581162            0.0   0.963281     26
# 2        1        0         0.581519            0.0   0.965723     26
# 3        1        1         0.572126            0.0   1.000000     26
# Train IIA: 0.95849 || Loss: 0.58031
# Valid IIA: 0.96328 || Loss: 0.58152
# Epoch 27
# Batch 9984/10000 IIA: 1.0 Loss: 0.5339545011520386
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566627      0.0  0.999801     27
# 1        0        1   0.579304      0.0  0.960140     27
# 2        1        0   0.579460      0.0  0.959662     27
# 3        1        1   0.566627      0.0  0.999860     27
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   0.999902     27
# 1        0        1         0.580503            0.0   0.967187     27
# 2        1        0         0.581025            0.0   0.966699     27
# 3        1        1         0.572126            0.0   1.000000     27
# Train IIA: 0.95966 || Loss: 0.57946
# Valid IIA: 0.9667 || Loss: 0.58103
# Epoch 28
# Batch 9984/10000 IIA: 1.0 Loss: 0.5320016145706177
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566562      0.0  0.999900     28
# 1        0        1   0.578506      0.0  0.959853     28
# 2        1        0   0.578209      0.0  0.961404     28
# 3        1        1   0.566562      0.0  0.999841     28
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     28
# 1        0        1         0.579289            0.0   0.970605     28
# 2        1        0         0.579498            0.0   0.968652     28
# 3        1        1         0.572126            0.0   1.000000     28
# Train IIA: 0.95985 || Loss: 0.57851
# Valid IIA: 0.96865 || Loss: 0.5795
# Epoch 29
# Batch 9984/10000 IIA: 1.0 Loss: 0.5324680805206299
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566478      0.0  0.999821     29
# 1        0        1   0.578846      0.0  0.960069     29
# 2        1        0   0.578860      0.0  0.961898     29
# 3        1        1   0.566478      0.0  0.999880     29
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     29
# 1        0        1         0.581945            0.0   0.963867     29
# 2        1        0         0.580962            0.0   0.966016     29
# 3        1        1         0.572126            0.0   0.999902     29
# Train IIA: 0.96007 || Loss: 0.57886
# Valid IIA: 0.96387 || Loss: 0.58195
# Epoch 30
# Batch 9984/10000 IIA: 1.0 Loss: 0.5314103364944458
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566335      0.0  0.999860     30
# 1        0        1   0.578001      0.0  0.961173     30
# 2        1        0   0.577911      0.0  0.961384     30
# 3        1        1   0.566335      0.0  0.999761     30
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     30
# 1        0        1         0.579168            0.0   0.968555     30
# 2        1        0         0.578873            0.0   0.969824     30
# 3        1        1         0.572126            0.0   1.000000     30
# Train IIA: 0.96117 || Loss: 0.578
# Valid IIA: 0.96855 || Loss: 0.57917
# Epoch 31
# Batch 9984/10000 IIA: 1.0 Loss: 0.5353235602378845
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566474      0.0  0.999900     31
# 1        0        1   0.577590      0.0  0.961838     31
# 2        1        0   0.577676      0.0  0.962616     31
# 3        1        1   0.566474      0.0  0.999880     31
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     31
# 1        0        1         0.580022            0.0   0.967480     31
# 2        1        0         0.579668            0.0   0.968652     31
# 3        1        1         0.572126            0.0   1.000000     31
# Train IIA: 0.96184 || Loss: 0.57768
# Valid IIA: 0.96748 || Loss: 0.58002
# Epoch 32
# Batch 9984/10000 IIA: 1.0 Loss: 0.5320492386817932
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566439      0.0  0.999860     32
# 1        0        1   0.578073      0.0  0.961049     32
# 2        1        0   0.577676      0.0  0.961101     32
# 3        1        1   0.566439      0.0  0.999801     32
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     32
# 1        0        1         0.581616            0.0   0.966211     32
# 2        1        0         0.581764            0.0   0.963770     32
# 3        1        1         0.572126            0.0   1.000000     32
# Train IIA: 0.96105 || Loss: 0.57807
# Valid IIA: 0.96377 || Loss: 0.58176
# Epoch 33
# Batch 9984/10000 IIA: 1.0 Loss: 0.5333718061447144
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566730      0.0  0.999821     33
# 1        0        1   0.577377      0.0  0.962767     33
# 2        1        0   0.577397      0.0  0.963724     33
# 3        1        1   0.566730      0.0  0.999801     33
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     33
# 1        0        1         0.578804            0.0   0.970605     33
# 2        1        0         0.578874            0.0   0.970117     33
# 3        1        1         0.572126            0.0   0.999902     33
# Train IIA: 0.96277 || Loss: 0.5774
# Valid IIA: 0.97012 || Loss: 0.57887
# Epoch 34
# Batch 9984/10000 IIA: 1.0 Loss: 0.5303912162780762
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566447      0.0  0.999860     34
# 1        0        1   0.576545      0.0  0.964322     34
# 2        1        0   0.576723      0.0  0.964609     34
# 3        1        1   0.566447      0.0  0.999900     34
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     34
# 1        0        1         0.578342            0.0   0.971191     34
# 2        1        0         0.578136            0.0   0.970313     34
# 3        1        1         0.572126            0.0   1.000000     34
# Train IIA: 0.96432 || Loss: 0.57672
# Valid IIA: 0.97031 || Loss: 0.57834
# Epoch 35
# Batch 9984/10000 IIA: 1.0 Loss: 0.5283098816871643
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566346      0.0  0.999801     35
# 1        0        1   0.576980      0.0  0.961886     35
# 2        1        0   0.576798      0.0  0.963915     35
# 3        1        1   0.566346      0.0  0.999920     35
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     35
# 1        0        1         0.577466            0.0   0.972656     35
# 2        1        0         0.577571            0.0   0.975391     35
# 3        1        1         0.572126            0.0   0.999902     35
# Train IIA: 0.96189 || Loss: 0.57698
# Valid IIA: 0.97266 || Loss: 0.57757
# Epoch 36
# Batch 9984/10000 IIA: 1.0 Loss: 0.5302907228469849
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566381      0.0  0.999860     36
# 1        0        1   0.576846      0.0  0.964110     36
# 2        1        0   0.576517      0.0  0.964971     36
# 3        1        1   0.566381      0.0  0.999841     36
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     36
# 1        0        1         0.578044            0.0   0.970313     36
# 2        1        0         0.577998            0.0   0.973437     36
# 3        1        1         0.572126            0.0   1.000000     36
# Train IIA: 0.96411 || Loss: 0.57685
# Valid IIA: 0.97031 || Loss: 0.57804
# Epoch 37
# Batch 9984/10000 IIA: 1.0 Loss: 0.5280551910400391
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566250      0.0  0.999880     37
# 1        0        1   0.576444      0.0  0.964338     37
# 2        1        0   0.575940      0.0  0.965780     37
# 3        1        1   0.566250      0.0  0.999860     37
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     37
# 1        0        1         0.577283            0.0   0.973047     37
# 2        1        0         0.577302            0.0   0.974219     37
# 3        1        1         0.572126            0.0   1.000000     37
# Train IIA: 0.96434 || Loss: 0.57644
# Valid IIA: 0.97305 || Loss: 0.5773
# Epoch 38
# Batch 9984/10000 IIA: 1.0 Loss: 0.5276355743408203
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566573      0.0  0.999880     38
# 1        0        1   0.576508      0.0  0.965087     38
# 2        1        0   0.576272      0.0  0.966103     38
# 3        1        1   0.566573      0.0  0.999841     38
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     38
# 1        0        1         0.577610            0.0   0.970605     38
# 2        1        0         0.577900            0.0   0.974902     38
# 3        1        1         0.572126            0.0   1.000000     38
# Train IIA: 0.96509 || Loss: 0.57651
# Valid IIA: 0.97061 || Loss: 0.5779
# Epoch 39
# Batch 9984/10000 IIA: 1.0 Loss: 0.5274254083633423
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566809      0.0  0.999841     39
# 1        0        1   0.576565      0.0  0.964066     39
# 2        1        0   0.576371      0.0  0.964864     39
# 3        1        1   0.566809      0.0  0.999860     39
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     39
# 1        0        1         0.576529            0.0   0.975684     39
# 2        1        0         0.576362            0.0   0.975488     39
# 3        1        1         0.572126            0.0   1.000000     39
# Train IIA: 0.96407 || Loss: 0.57657
# Valid IIA: 0.97549 || Loss: 0.57653
# Epoch 40
# Batch 9984/10000 IIA: 1.0 Loss: 0.527500569820404
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566723      0.0  0.999900     40
# 1        0        1   0.576228      0.0  0.965772     40
# 2        1        0   0.576328      0.0  0.965908     40
# 3        1        1   0.566723      0.0  0.999821     40
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     40
# 1        0        1         0.578183            0.0   0.970605     40
# 2        1        0         0.578266            0.0   0.972461     40
# 3        1        1         0.572126            0.0   1.000000     40
# Train IIA: 0.96577 || Loss: 0.57633
# Valid IIA: 0.97061 || Loss: 0.57827
# Epoch 41
# Batch 9984/10000 IIA: 1.0 Loss: 0.5292894840240479
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566660      0.0  0.999821     41
# 1        0        1   0.576127      0.0  0.965310     41
# 2        1        0   0.576499      0.0  0.963895     41
# 3        1        1   0.566660      0.0  0.999860     41
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     41
# 1        0        1         0.577271            0.0   0.974512     41
# 2        1        0         0.577276            0.0   0.973633     41
# 3        1        1         0.572126            0.0   1.000000     41
# Train IIA: 0.9639 || Loss: 0.5765
# Valid IIA: 0.97363 || Loss: 0.57728
# Epoch 42
# Batch 9984/10000 IIA: 1.0 Loss: 0.527276873588562
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566598      0.0  0.999920     42
# 1        0        1   0.575992      0.0  0.965549     42
# 2        1        0   0.575695      0.0  0.966163     42
# 3        1        1   0.566598      0.0  0.999841     42
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     42
# 1        0        1         0.576233            0.0   0.975391     42
# 2        1        0         0.576129            0.0   0.977344     42
# 3        1        1         0.572126            0.0   1.000000     42
# Train IIA: 0.96555 || Loss: 0.57599
# Valid IIA: 0.97539 || Loss: 0.57623
# Epoch 43
# Batch 9984/10000 IIA: 1.0 Loss: 0.5305894613265991
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566650      0.0  0.999841     43
# 1        0        1   0.575716      0.0  0.965605     43
# 2        1        0   0.576443      0.0  0.965218     43
# 3        1        1   0.566650      0.0  0.999841     43
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     43
# 1        0        1         0.576418            0.0   0.975977     43
# 2        1        0         0.576495            0.0   0.978027     43
# 3        1        1         0.572126            0.0   1.000000     43
# Train IIA: 0.96522 || Loss: 0.57644
# Valid IIA: 0.97598 || Loss: 0.5765
# Epoch 44
# Batch 9984/10000 IIA: 1.0 Loss: 0.5280270576477051
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566488      0.0  0.999781     44
# 1        0        1   0.575060      0.0  0.967231     44
# 2        1        0   0.574749      0.0  0.967331     44
# 3        1        1   0.566488      0.0  0.999860     44
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     44
# 1        0        1         0.576221            0.0   0.976855     44
# 2        1        0         0.576142            0.0   0.976562     44
# 3        1        1         0.572126            0.0   1.000000     44
# Train IIA: 0.96723 || Loss: 0.57506
# Valid IIA: 0.97656 || Loss: 0.57622
# Epoch 45
# Batch 9984/10000 IIA: 1.0 Loss: 0.5347068309783936
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566789      0.0  0.999880     45
# 1        0        1   0.575685      0.0  0.967351     45
# 2        1        0   0.575376      0.0  0.967044     45
# 3        1        1   0.566789      0.0  0.999801     45
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     45
# 1        0        1         0.587744            0.0   0.950879     45
# 2        1        0         0.587110            0.0   0.954980     45
# 3        1        1         0.572126            0.0   1.000000     45
# Train IIA: 0.96704 || Loss: 0.57568
# Valid IIA: 0.95088 || Loss: 0.58774
# Epoch 46
# Batch 9984/10000 IIA: 1.0 Loss: 0.5270593166351318
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566628      0.0  0.999821     46
# 1        0        1   0.575325      0.0  0.967088     46
# 2        1        0   0.575437      0.0  0.966833     46
# 3        1        1   0.566628      0.0  0.999841     46
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     46
# 1        0        1         0.578330            0.0   0.970313     46
# 2        1        0         0.578457            0.0   0.971875     46
# 3        1        1         0.572126            0.0   1.000000     46
# Train IIA: 0.96683 || Loss: 0.57544
# Valid IIA: 0.97031 || Loss: 0.57846
# Epoch 47
# Batch 9984/10000 IIA: 1.0 Loss: 0.5324351787567139
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566485      0.0  0.999860     47
# 1        0        1   0.575097      0.0  0.967502     47
# 2        1        0   0.574614      0.0  0.967207     47
# 3        1        1   0.566485      0.0  0.999900     47
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     47
# 1        0        1         0.579310            0.0   0.969336     47
# 2        1        0         0.579136            0.0   0.969336     47
# 3        1        1         0.572126            0.0   0.999902     47
# Train IIA: 0.96721 || Loss: 0.5751
# Valid IIA: 0.96934 || Loss: 0.57931
# Epoch 48
# Batch 9984/10000 IIA: 1.0 Loss: 0.5260593891143799
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566444      0.0  0.999781     48
# 1        0        1   0.574776      0.0  0.967997     48
# 2        1        0   0.574485      0.0  0.968443     48
# 3        1        1   0.566444      0.0  0.999860     48
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   0.999805     48
# 1        0        1         0.574978            0.0   0.979004     48
# 2        1        0         0.574999            0.0   0.979883     48
# 3        1        1         0.572126            0.0   1.000000     48
# Train IIA: 0.968 || Loss: 0.57478
# Valid IIA: 0.979 || Loss: 0.575
# Epoch 49
# Batch 9984/10000 IIA: 1.0 Loss: 0.5263921618461609
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566839      0.0  0.999880     49
# 1        0        1   0.575639      0.0  0.969392     49
# 2        1        0   0.575532      0.0  0.966693     49
# 3        1        1   0.566839      0.0  0.999801     49
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     49
# 1        0        1         0.574748            0.0   0.980469     49
# 2        1        0         0.574787            0.0   0.982031     49
# 3        1        1         0.572126            0.0   1.000000     49
# Train IIA: 0.96669 || Loss: 0.57564
# Valid IIA: 0.98047 || Loss: 0.57479
# Epoch 50
# Batch 9984/10000 IIA: 1.0 Loss: 0.5254679918289185
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566657      0.0  0.999880     50
# 1        0        1   0.575039      0.0  0.967407     50
# 2        1        0   0.575019      0.0  0.968802     50
# 3        1        1   0.566657      0.0  0.999821     50
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     50
# 1        0        1         0.574758            0.0   0.980664     50
# 2        1        0         0.574659            0.0   0.982227     50
# 3        1        1         0.572126            0.0   1.000000     50
# Train IIA: 0.96741 || Loss: 0.57504
# Valid IIA: 0.98066 || Loss: 0.57476
# Epoch 51
# Batch 9984/10000 IIA: 1.0 Loss: 0.5271943807601929
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566850      0.0  0.999900     51
# 1        0        1   0.575246      0.0  0.966833     51
# 2        1        0   0.575604      0.0  0.966350     51
# 3        1        1   0.566850      0.0  0.999880     51
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     51
# 1        0        1         0.578065            0.0   0.972656     51
# 2        1        0         0.577922            0.0   0.972168     51
# 3        1        1         0.572126            0.0   1.000000     51
# Train IIA: 0.96635 || Loss: 0.5756
# Valid IIA: 0.97217 || Loss: 0.57806
# Epoch 52
# Batch 9984/10000 IIA: 1.0 Loss: 0.5273077487945557
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566297      0.0  0.999821     52
# 1        0        1   0.574519      0.0  0.967829     52
# 2        1        0   0.574665      0.0  0.967407     52
# 3        1        1   0.566297      0.0  0.999841     52
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     52
# 1        0        1         0.577953            0.0   0.970605     52
# 2        1        0         0.577951            0.0   0.970605     52
# 3        1        1         0.572126            0.0   1.000000     52
# Train IIA: 0.96741 || Loss: 0.57466
# Valid IIA: 0.97061 || Loss: 0.57795
# Epoch 53
# Batch 9984/10000 IIA: 1.0 Loss: 0.5260434150695801
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566427      0.0  0.999860     53
# 1        0        1   0.574715      0.0  0.967399     53
# 2        1        0   0.574797      0.0  0.967690     53
# 3        1        1   0.566427      0.0  0.999880     53
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     53
# 1        0        1         0.575221            0.0   0.978516     53
# 2        1        0         0.575146            0.0   0.979883     53
# 3        1        1         0.572126            0.0   1.000000     53
# Train IIA: 0.9674 || Loss: 0.5748
# Valid IIA: 0.97852 || Loss: 0.57522
# Epoch 54
# Batch 9984/10000 IIA: 1.0 Loss: 0.5250774621963501
#    src_idx  trg_idx  actn_loss  cl_loss       acc  epoch
# 0        0        0   0.566513      0.0  0.999801     54
# 1        0        1   0.574884      0.0  0.967670     54
# 2        1        0   0.574643      0.0  0.968060     54
# 3        1        1   0.566513      0.0  0.999900     54
#    src_idx  trg_idx  valid_actn_loss  valid_cl_loss  valid_acc  epoch
# 0        0        0         0.572126            0.0   1.000000     54
# 1        0        1         0.575191            0.0   0.979395     54
# 2        1        0         0.575231            0.0   0.977441     54
# 3        1        1         0.572126            0.0   1.000000     54
# Train IIA: 0.96767 || Loss: 0.57488
# Valid IIA: 0.97744 || Loss: 0.57523
# Epoch 55
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1944293/1403313382.py", line 22, in <module>
#     train_df = train_mas_alignment_one_epoch(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/grantsrb/src/mas/vision/vis_utils.py", line 376, in train_mas_alignment_one_epoch
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/torch/_tensor.py", line 647, in backward
#     torch.autograd.backward(
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/torch/autograd/__init__.py", line 354, in backward
#     _engine_run_backward(
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/torch/autograd/graph.py", line 829, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "/home/grantsrb/anaconda3/lib/python3.11/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
train_df = pd.concat(train_dfs)
valid_df = pd.concat(valid_dfs)

# %%
import datetime

def get_timestamp():
    return datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
train_df.columns = ["train_"+col if col in cols else col for col in train_df.columns]
valid_df.columns = ["valid_"+col if col in cols else col for col in valid_df.columns]
main_df = pd.merge(train_df, valid_df, on=groups+["epoch"])

timestamp = get_timestamp()
m1 = model_names[0].replace("/", "_")
m2 = model_names[1].replace("/", "_")
main_df.to_csv(f"csvs/{m1}_{m2}_mas_results_{timestamp}.csv", index=False, header=True)
main_df.head()
# Out:
#    src_idx  trg_idx  train_actn_loss  train_cl_loss  train_acc  epoch  \
# 0        0        0         0.566333            0.0   0.999841      0
# 1        0        1         0.688486            0.0   0.874251      0
# 2        1        0         0.689693            0.0   0.872684      0
# 3        1        1         0.566333            0.0   0.999920      0
# 4        0        0         0.566701            0.0   0.999880      1
#
#    valid_actn_loss  valid_cl_loss  valid_acc
# 0         0.572126            0.0   1.000000
# 1         0.694260            0.0   0.873145
# 2         0.692942            0.0   0.872363
# 3         0.572126            0.0   1.000000
# 4         0.572126            0.0   1.000000

# %% [markdown]
# # 6. Evaluate results

# %%
main_df = pd.read_csv(f"csvs/{m1}_{m2}_mas_results_{timestamp}.csv")

# %%
main_df["direction"] = main_df["src_idx"].astype(str) + "->" + main_df["trg_idx"].astype(str)
all_df = main_df[["direction","epoch"]+cols]
cols = ["train_acc","valid_acc", "train_actn_loss", "valid_actn_loss"]
all_dfs = [all_df]
for agg in ["min","max","mean"]:
    df = all_df.groupby(["epoch"])[cols].agg(agg).reset_index()
    df["epoch"] = df.index
    df["direction"] = agg
    all_dfs.append(df)
all_df = pd.concat(all_dfs, sort=True)
all_df.head()

# %%
set(all_df["direction"])
# Out:
# {'0->0', '0->1', '1->0', '1->1', 'max', 'mean', 'min'}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig = plt.figure(figsize=(7,7))
ax = plt.gca()

plot_df = all_df[all_df["direction"].isin({"min", "1->0", "0->1"})]
sns.lineplot(
    data=plot_df,
    x="epoch",
    y="train_acc",
    hue="direction",
    ax=ax,
    legend=False,
    palette=sns.color_palette("bright"),
)

sns.lineplot(
    data=plot_df,
    x="epoch",
    y="valid_acc",
    hue="direction",
    ax=ax,
    legend=True,
    palette=sns.color_palette("dark"),
)

ax.set_xlabel("Epoch")
ax.set_ylabel("Accuracy")
ax.set_title("Accuracy of MAS Alignment")

plt.show()
# Out:
# /tmp/ipykernel_1944293/1755418564.py:8: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.lineplot(
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /tmp/ipykernel_1944293/1755418564.py:18: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.lineplot(
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
fig = plt.figure(figsize=(7,7))
ax = plt.gca()

plot_df = all_df[all_df["direction"].isin({"max", "min", "1->0", "0->1"})]
sns.lineplot(
    data=plot_df,
    x="epoch",
    y="train_actn_loss",
    hue="direction",
    legend=False,
    ax=ax,
    palette=sns.color_palette("bright"),
)

sns.lineplot(
    data=plot_df,
    x="epoch",
    y="valid_actn_loss",
    hue="direction",
    ax=ax,
    legend=True,
    palette=sns.color_palette("dark"),
)

ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_title("Loss of MAS Alignment")

plt.show()
# Out:
# /tmp/ipykernel_1944293/2069286042.py:5: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.lineplot(
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /tmp/ipykernel_1944293/2069286042.py:15: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.lineplot(
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/grantsrb/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
