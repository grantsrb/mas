# %%
from vis_training import get_datasets

data_root = "/data2/grantsrb/torch_datasets"
dataset_name = "mnist"

train_ds, test_ds = get_datasets(dataset_name, data_root,)
train_ds
# Out:
# Loading mnist...
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /data2/grantsrb/torch_datasets
#     Split: Train

# %%
dir(train_ds)
# Out:
# ['__add__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_exists',
#  '_check_legacy_exist',
#  '_format_transform_repr',
#  '_is_protocol',
#  '_load_data',
#  '_load_legacy_data',
#  '_repr_indent',
#  'class_to_idx',
#  'classes',
#  'data',
#  'download',
#  'extra_repr',
#  'mirrors',
#  'processed_folder',
#  'raw_folder',
#  'resources',
#  'root',
#  'target_transform',
#  'targets',
#  'test_data',
#  'test_file',
#  'test_labels',
# ...

# %%
import numpy as np
idxs = np.arange(5)
len(train_ds.data[idxs])
len(np.asarray(train_ds.targets)[idxs])
# Out:
# 5
